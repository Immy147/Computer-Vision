# %%
#load libraries
import cv2
import matplotlib.pyplot as plt

#load the images

image = cv2.imread('im33.jpg')

#Change the color
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


#canny edge detection
edges = cv2.Canny(image, 100, 200)
#Show the Output

plt.imshow(edges)
plt.show()
